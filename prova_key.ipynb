# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd
import librosa
import librosa.display
import src.chroma.keyfinder as kf

# %%
# this audio takes a long time to load because it has a very high sampling rate; be patient.
#audio_path = "db/giantsteps-key-dataset/audio/1004923.LOFI.mp3"

# the load function generates a tuple consisting of an audio object y and its sampling rate sr
filename = "db/giantsteps-key-dataset/audio/1004923.LOFI.mp3"

y, sr = librosa.load(filename)
# this function filters out the harmonic part of the sound file from the percussive part, allowing for
# more accurate harmonic analysis
y_harmonic, y_percussive = librosa.effects.hpss(y)
ipd.Audio(filename)
# Out:
# /tmp/ipykernel_2983/578588817.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(filename)
# /home/polmarin/.local/lib/python3.8/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
unebarque_fsharp_min = kf.Tonal_Fragment(y_harmonic, sr, tend=22)
unebarque_fsharp_min.print_chroma()
# Out:
# C 	 0.543
# C# 	 0.323
# D 	 0.258
# D# 	 0.446
# E 	 0.915
# F 	 1.000
# F# 	 0.615
# G 	 0.363
# G# 	 0.229
# A 	 0.166
# A# 	 0.156
# B 	 0.192

# %%
unebarque_fsharp_min.print_key()
# Out:
# likely key: F minor, correlation: 0.422
# also possible: C major, correlation: 0.38

# %%
import soundfile

#ipd.Audio(audio_path)

# %%
soundfile.read("proves/angry-birds-theme-song.mp3")
soundfile.read()
# Out:
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# /home/polmarin/DRCAV/DRCAV1-audio-project/prova_key.ipynb Cell 6 in 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/polmarin/DRCAV/DRCAV1-audio-project/prova_key.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> soundfile.read("proves/angry-birds-theme-song.mp3")
#
# File ~/.local/lib/python3.8/site-packages/soundfile.py:285, in read(file, frames, start, stop, dtype, always_2d, fill_value, out, samplerate, channels, format, subtype, endian, closefd)
#     199 def read(file, frames=-1, start=0, stop=None, dtype='float64', always_2d=False,
#     200          fill_value=None, out=None, samplerate=None, channels=None,
#     201          format=None, subtype=None, endian=None, closefd=True):
#     202     """Provide audio data from a sound file as NumPy array.
#     203
#     204     By default, the whole file is read from the beginning, but the
#    (...)
#     283
#     284     """
# --> 285     with SoundFile(file, 'r', samplerate, channels,
#     286                    subtype, endian, format, closefd) as f:
#     287         frames = f._prepare_read(start, stop, frames)
#     288         data = f.read(frames, dtype, always_2d, fill_value, out)
#
# File ~/.local/lib/python3.8/site-packages/soundfile.py:658, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     655 self._mode = mode
#     656 self._info = _create_info_struct(file, mode, samplerate, channels,
#     657                                  format, subtype, endian)
# --> 658 self._file = self._open(file, mode_int, closefd)
#     659 if set(mode).issuperset('r+') and self.seekable():
#     660     # Move write position to 0 (like in Python file objects)
#     661     self.seek(0)
#
# File ~/.local/lib/python3.8/site-packages/soundfile.py:1216, in SoundFile._open(self, file, mode_int, closefd)
#    1213 if file_ptr == _ffi.NULL:
#    1214     # get the actual error code
#    1215     err = _snd.sf_error(file_ptr)
# -> 1216     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
#    1217 if mode_int == _snd.SFM_WRITE:
#    1218     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1219     # when opening a named pipe in SFM_WRITE mode.
#    1220     # See http://github.com/erikd/libsndfile/issues/77.
#    1221     self._info.frames = 0
#
# LibsndfileError: Error opening 'proves/angry-birds-theme-song.mp3': File contains data in an unknown format.

# %%
librosa.load("db/giantsteps-key-dataset/audiowav/1004923.LOFI.wav")
# Out:
# /tmp/ipykernel_1953/1827536974.py:1: UserWarning: PySoundFile failed. Trying audioread instead.
#   librosa.load("db/giantsteps-key-dataset/audiowav/1004923.LOFI.wav")
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/librosa/core/audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     175 try:
# --> 176     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178 except sf.SoundFileRuntimeError as exc:
#     179     # If soundfile failed, try audioread instead
#
# File ~/.local/lib/python3.8/site-packages/librosa/core/audio.py:209, in __soundfile_load(path, offset, duration, dtype)
#     207 else:
#     208     # Otherwise, create the soundfile object
# --> 209     context = sf.SoundFile(path)
#     211 with context as sf_desc:
#
# File ~/.local/lib/python3.8/site-packages/soundfile.py:658, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     656 self._info = _create_info_struct(file, mode, samplerate, channels,
#     657                                  format, subtype, endian)
# --> 658 self._file = self._open(file, mode_int, closefd)
#     659 if set(mode).issuperset('r+') and self.seekable():
#     660     # Move write position to 0 (like in Python file objects)
#
# File ~/.local/lib/python3.8/site-packages/soundfile.py:1216, in SoundFile._open(self, file, mode_int, closefd)
#    1215     err = _snd.sf_error(file_ptr)
# -> 1216     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
#    1217 if mode_int == _snd.SFM_WRITE:
#    1218     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1219     # when opening a named pipe in SFM_WRITE mode.
#    1220     # See http://github.com/erikd/libsndfile/issues/77.
#
# LibsndfileError: Error opening 'db/giantsteps-key-dataset/audiowav/1004923.LOFI.wav': File contains data in an unknown format.
#
# During handling of the above exception, another exception occurred:
#
# NoBackendError                            Traceback (most recent call last)
# /home/polmarin/DRCAV/DRCAV1-audio-project/prova_key.ipynb Cell 7 in 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/polmarin/DRCAV/DRCAV1-audio-project/prova_key.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> librosa.load("db/giantsteps-key-dataset/audiowav/1004923.LOFI.wav")
#
# File ~/.local/lib/python3.8/site-packages/librosa/core/audio.py:184, in load(path, sr, mono, offset, duration, dtype, res_type)
#     180 if isinstance(path, (str, pathlib.PurePath)):
#     181     warnings.warn(
#     182         "PySoundFile failed. Trying audioread instead.", stacklevel=2
#     183     )
# --> 184     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     185 else:
#     186     raise exc
#
# File ~/.local/lib/python3.8/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/.local/lib/python3.8/site-packages/librosa/util/decorators.py:60, in deprecated.<locals>.__wrapper(func, *args, **kwargs)
#      51 """Warn the user, and then proceed."""
#      52 warnings.warn(
#      53     "{:s}.{:s}\n\tDeprecated as of librosa version {:s}."
#      54     "\n\tIt will be removed in librosa version {:s}.".format(
#    (...)
#      58     stacklevel=3,  # Would be 2, but the decorator adds a level
#      59 )
# ---> 60 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/librosa/core/audio.py:241, in __audioread_load(path, offset, duration, dtype)
#     238     reader = path
#     239 else:
#     240     # If the input was not an audioread object, try to open it
# --> 241     reader = audioread.audio_open(path)
#     243 with reader as input_file:
#     244     sr_native = input_file.samplerate
#
# File ~/.local/lib/python3.8/site-packages/audioread/__init__.py:132, in audio_open(path, backends)
#     129         pass
#     131 # All backends failed!
# --> 132 raise NoBackendError()
#
# NoBackendError:
